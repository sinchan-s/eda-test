# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
lb = pd.read_csv('leads_basic_details.csv')
ld = pd.read_csv('leads_demo_watched_details.csv')
li = pd.read_csv('leads_interaction_details.csv')
lr = pd.read_csv('leads_reasons_for_no_interest.csv')
sm = pd.read_csv('sales_managers_assigned_leads_details.csv')

# %%
def unique_values(dataset):
    for i in dataset.columns:
        print(f'\nUnique: {i.upper()}')
        unik_values = dataset[i].unique()
        print(f'Total unique values: {len(unik_values)}')
        print(unik_values)

# %%
lb.head()
# Out:
#    lead_id  age  gender   current_city current_education    parent_occupation  \
# 0  USR1001   16  FEMALE      Hyderabad      Intermediate     Private Employee
# 1  USR1002   20    MALE      Bengaluru            B.Tech             Business
# 2  USR1003   20  FEMALE  Visakhapatnam            B.Tech               Lawyer
# 3  USR1004   16    MALE         Mumbai      Intermediate          IT Employee
# 4  USR1005   16    MALE        Chennai      Intermediate  Government Employee
#
#   lead_gen_source
# 0    social_media
# 1  user_referrals
# 2  user_referrals
# 3  user_referrals
# 4  user_referrals

# %%
unique_values(lb)
# Out:
# Unique: LEAD_ID
# Total unique values: 360
# ['USR1001' 'USR1002' 'USR1003' 'USR1004' 'USR1005' 'USR1006' 'USR1007'
#  'USR1008' 'USR1009' 'USR1010' 'USR1011' 'USR1012' 'USR1013' 'USR1014'
#  'USR1015' 'USR1016' 'USR1017' 'USR1018' 'USR1019' 'USR1020' 'USR1021'
#  'USR1022' 'USR1023' 'USR1024' 'USR1025' 'USR1026' 'USR1027' 'USR1028'
#  'USR1029' 'USR1030' 'USR1031' 'USR1032' 'USR1033' 'USR1034' 'USR1035'
#  'USR1036' 'USR1037' 'USR1038' 'USR1039' 'USR1040' 'USR1041' 'USR1042'
#  'USR1043' 'USR1044' 'USR1045' 'USR1046' 'USR1047' 'USR1048' 'USR1049'
#  'USR1050' 'USR1051' 'USR1052' 'USR1053' 'USR1054' 'USR1055' 'USR1056'
#  'USR1057' 'USR1058' 'USR1059' 'USR1060' 'USR1061' 'USR1062' 'USR1063'
#  'USR1064' 'USR1065' 'USR1066' 'USR1067' 'USR1068' 'USR1069' 'USR1070'
#  'USR1071' 'USR1072' 'USR1073' 'USR1074' 'USR1075' 'USR1076' 'USR1077'
#  'USR1078' 'USR1079' 'USR1080' 'USR1081' 'USR1082' 'USR1083' 'USR1084'
#  'USR1085' 'USR1086' 'USR1087' 'USR1088' 'USR1089' 'USR1090' 'USR1091'
# ...

# %%
lb.loc[lb['age']>100]
# Out:
#      lead_id  age  gender current_city current_education parent_occupation  \
# 17   USR1018  211    MALE    Hyderabad            Degree       IT Employee
# 300  USR1301  116  FEMALE    Hyderabad      Intermediate  Private Employee
#
#     lead_gen_source
# 17     social_media
# 300    social_media

# %%
new_lb = lb.loc[lb['age']<100]

# %%
new_lb.to_csv("new_leads_basic_details.csv", index=False)

# %%
ld.head()
# Out:
#    lead_id demo_watched_date language  watched_percentage
# 0  USR1002          1/4/2022   Telugu                  42
# 1  USR1003          1/7/2022   Telugu                  81
# 2  USR1004          1/2/2022   Telugu                  35
# 3  USR1005          1/3/2022    Hindi                  38
# 4  USR1006         1/12/2022    Hindi                  54

# %%
unique_values(ld)
# Out:
# Unique: LEAD_ID
# Total unique values: 194
# ['USR1002' 'USR1003' 'USR1004' 'USR1005' 'USR1006' 'USR1007' 'USR1008'
#  'USR1009' 'USR1010' 'USR1011' 'USR1012' 'USR1013' 'USR1014' 'USR1015'
#  'USR1016' 'USR1017' 'USR1018' 'USR1019' 'USR1020' 'USR1021' 'USR1022'
#  'USR1023' 'USR1024' 'USR1025' 'USR1026' 'USR1027' 'USR1028' 'USR1029'
#  'USR1030' 'USR1031' 'USR1032' 'USR1033' 'USR1034' 'USR1035' 'USR1036'
#  'USR1037' 'USR1038' 'USR1039' 'USR1040' 'USR1041' 'USR1042' 'USR1043'
#  'USR1044' 'USR1045' 'USR1046' 'USR1047' 'USR1050' 'USR1051' 'USR1052'
#  'USR1053' 'USR1055' 'USR1057' 'USR1058' 'USR1062' 'USR1063' 'USR1065'
#  'USR1067' 'USR1070' 'USR1071' 'USR1072' 'USR1073' 'USR1075' 'USR1077'
#  'USR1078' 'USR1082' 'USR1083' 'USR1087' 'USR1090' 'USR1091' 'USR1092'
#  'USR1093' 'USR1095' 'USR1097' 'USR1098' 'USR1102' 'USR1103' 'USR1105'
#  'USR1107' 'USR1110' 'USR1111' 'USR1112' 'USR1113' 'USR1115' 'USR1117'
#  'USR1118' 'USR1122' 'USR1123' 'USR1127' 'USR1130' 'USR1131' 'USR1132'
# ...

# %%
ld.loc[ld.watched_percentage>100]
# Out:
#      lead_id demo_watched_date language  watched_percentage
# 94   USR1138         2/20/2022  English                 510
# 133  USR1213         1/20/2022   Telugu                 233

# %%
new_ld = ld.loc[ld.watched_percentage<=100]
new_ld
# Out:
#      lead_id demo_watched_date language  watched_percentage
# 0    USR1002          1/4/2022   Telugu                  42
# 1    USR1003          1/7/2022   Telugu                  81
# 2    USR1004          1/2/2022   Telugu                  35
# 3    USR1005          1/3/2022    Hindi                  38
# 4    USR1006         1/12/2022    Hindi                  54
# ..       ...               ...      ...                 ...
# 189  USR1317         2/25/2022  English                  48
# 190  USR1318         2/25/2022  English                  83
# 191  USR1319         2/28/2022  English                  84
# 192  USR1343         1/25/2022  English                  68
# 193  USR1348         2/27/2022  English                  72
#
# [192 rows x 4 columns]

# %%
new_ld.to_csv('new_leads_demo_watched_details.csv', index=False)

# %%
li.head()
# Out:
#    jnr_sm_id  lead_id lead_stage call_done_date call_status  \
# 0  JNR1001MG  USR1001       lead       1/2/2022  successful
# 1  JNR1001MG  USR1001       lead       1/2/2022  successful
# 2  JNR1001MG  USR1002       lead       1/3/2022  successful
# 3  JNR1001MG  USR1002       lead       1/4/2022  successful
# 4  JNR1001MG  USR1002  awareness       1/5/2022  successful
#
#           call_reason
# 0   lead_introduction
# 1       demo_schedule
# 2   lead_introduction
# 3       demo_schedule
# 4  post_demo_followup

# %%
unique_values(li)
# Out:
# Unique: JNR_SM_ID
# Total unique values: 16
# ['JNR1001MG' 'JNR1002MG' 'JNR1003MG' 'JNR1004MG' 'JNR1005MG' 'JNR1006MG'
#  'JNR1007MG' 'JNR1008MG' 'JNR1009MG' 'JNR1010MG' 'JNR1011MG' 'JNR1012MG'
#  'JNR1013MG' 'JNR1014MG' 'JNR1015MG' 'JNR1016MG']
#
# Unique: LEAD_ID
# Total unique values: 358
# ['USR1001' 'USR1002' 'USR1003' 'USR1004' 'USR1005' 'USR1006' 'USR1007'
#  'USR1008' 'USR1009' 'USR1010' 'USR1011' 'USR1012' 'USR1013' 'USR1014'
#  'USR1015' 'USR1016' 'USR1017' 'USR1018' 'USR1019' 'USR1020' 'USR1021'
#  'USR1022' 'USR1023' 'USR1024' 'USR1025' 'USR1026' 'USR1027' 'USR1028'
#  'USR1029' 'USR1030' 'USR1031' 'USR1032' 'USR1033' 'USR1034' 'USR1035'
#  'USR1036' 'USR1037' 'USR1038' 'USR1039' 'USR1040' 'USR1041' 'USR1042'
#  'USR1043' 'USR1044' 'USR1045' 'USR1046' 'USR1047' 'USR1048' 'USR1049'
#  'USR1050' 'USR1051' 'USR1052' 'USR1053' 'USR1054' 'USR1055' 'USR1056'
#  'USR1057' 'USR1058' 'USR1059' 'USR1060' 'USR1061' 'USR1062' 'USR1063'
# ...

# %%
lr.head()
# Out:
#    lead_id reasons_for_not_interested_in_demo  \
# 0  USR1001                No time for student
# 1  USR1003                                NaN
# 2  USR1004                                NaN
# 3  USR1005                                NaN
# 4  USR1006                                NaN
#
#   reasons_for_not_interested_to_consider reasons_for_not_interested_to_convert
# 0                                    NaN                                   NaN
# 1                    No time for student                                   NaN
# 2                  Wants offline classes                                   NaN
# 3                           Can't afford                                   NaN
# 4       Student not interested in domain                                   NaN

# %%
unique_values(lr)
# Out:
# Unique: LEAD_ID
# Total unique values: 294
# ['USR1001' 'USR1003' 'USR1004' 'USR1005' 'USR1006' 'USR1008' 'USR1009'
#  'USR1010' 'USR1014' 'USR1015' 'USR1016' 'USR1018' 'USR1019' 'USR1020'
#  'USR1021' 'USR1024' 'USR1026' 'USR1027' 'USR1028' 'USR1029' 'USR1030'
#  'USR1034' 'USR1035' 'USR1036' 'USR1038' 'USR1039' 'USR1040' 'USR1041'
#  'USR1043' 'USR1044' 'USR1045' 'USR1046' 'USR1048' 'USR1049' 'USR1050'
#  'USR1054' 'USR1055' 'USR1056' 'USR1058' 'USR1059' 'USR1060' 'USR1061'
#  'USR1064' 'USR1065' 'USR1066' 'USR1067' 'USR1068' 'USR1069' 'USR1070'
#  'USR1071' 'USR1074' 'USR1075' 'USR1076' 'USR1077' 'USR1078' 'USR1079'
#  'USR1080' 'USR1081' 'USR1082' 'USR1083' 'USR1084' 'USR1085' 'USR1086'
#  'USR1087' 'USR1088' 'USR1089' 'USR1090' 'USR1091' 'USR1094' 'USR1095'
#  'USR1096' 'USR1097' 'USR1098' 'USR1099' 'USR1100' 'USR1101' 'USR1104'
#  'USR1105' 'USR1106' 'USR1107' 'USR1108' 'USR1109' 'USR1110' 'USR1111'
#  'USR1114' 'USR1115' 'USR1117' 'USR1118' 'USR1119' 'USR1120' 'USR1121'
# ...

# %%
lr.loc[lr['reasons_for_not_interested_in_demo']=='Cannot afford']
# Out:
#      lead_id reasons_for_not_interested_in_demo  \
# 283  USR1350                      Cannot afford
# 284  USR1351                      Cannot afford
# 289  USR1356                      Cannot afford
# 290  USR1357                      Cannot afford
#
#     reasons_for_not_interested_to_consider  \
# 283                                    NaN
# 284                                    NaN
# 289                                    NaN
# 290                                    NaN
#
#     reasons_for_not_interested_to_convert
# 283                                   NaN
# 284                                   NaN
# 289                                   NaN
# 290                                   NaN

# %%
lr.loc[lr['reasons_for_not_interested_in_demo']=='Cannot afford','reasons_for_not_interested_in_demo']="Can't afford"

# %%
new_lr = lr.loc[lr['reasons_for_not_interested_in_demo']=="Can't afford"]
new_lr
# Out:
#      lead_id reasons_for_not_interested_in_demo  \
# 37   USR1056                       Can't afford
# 42   USR1064                       Can't afford
# 47   USR1069                       Can't afford
# 60   USR1084                       Can't afford
# 74   USR1100                       Can't afford
# 80   USR1108                       Can't afford
# 88   USR1119                       Can't afford
# 93   USR1124                       Can't afford
# 94   USR1125                       Can't afford
# 98   USR1129                       Can't afford
# 103  USR1136                       Can't afford
# 106  USR1139                       Can't afford
# 108  USR1141                       Can't afford
# 111  USR1146                       Can't afford
# 114  USR1149                       Can't afford
# 127  USR1164                       Can't afford
# 128  USR1165                       Can't afford
# 132  USR1169                       Can't afford
# ...

# %%
new_lr['reasons_for_not_interested_in_demo'].unique()
# Out:
# array(["Can't afford"], dtype=object)

# %%
new_lr.to_csv('new_leads_reasons_for_no_interest.csv', index=False)

# %%
sm.head()
# Out:
#   snr_sm_id  jnr_sm_id assigned_date  cycle  lead_id
# 0  SNR501MG  JNR1001MG      1/1/2022      1  USR1001
# 1  SNR501MG  JNR1001MG      1/1/2022      1  USR1002
# 2  SNR501MG  JNR1001MG      1/1/2022      1  USR1003
# 3  SNR501MG  JNR1001MG      1/1/2022      1  USR1004
# 4  SNR501MG  JNR1001MG      1/1/2022      1  USR1005

# %%
unique_values(sm)
# Out:
# Unique: SNR_SM_ID
# Total unique values: 4
# ['SNR501MG' 'SNR502MG' 'SNR503MG' 'SNR504MG']
#
# Unique: JNR_SM_ID
# Total unique values: 16
# ['JNR1001MG' 'JNR1002MG' 'JNR1003MG' 'JNR1004MG' 'JNR1005MG' 'JNR1006MG'
#  'JNR1007MG' 'JNR1008MG' 'JNR1009MG' 'JNR1010MG' 'JNR1011MG' 'JNR1012MG'
#  'JNR1013MG' 'JNR1014MG' 'JNR1015MG' 'JNR1016MG']
#
# Unique: ASSIGNED_DATE
# Total unique values: 4
# ['1/1/2022' '1/8/2022' '1/15/2022' '2/19/2022']
#
# Unique: CYCLE
# Total unique values: 4
# [1 2 3 4]
#
# Unique: LEAD_ID
# Total unique values: 360
# ['USR1001' 'USR1002' 'USR1003' 'USR1004' 'USR1005' 'USR1006' 'USR1007'
#  'USR1008' 'USR1009' 'USR1010' 'USR1011' 'USR1012' 'USR1013' 'USR1014'
#  'USR1015' 'USR1016' 'USR1017' 'USR1018' 'USR1019' 'USR1020' 'USR1021'
#  'USR1022' 'USR1023' 'USR1024' 'USR1025' 'USR1026' 'USR1027' 'USR1028'
#  'USR1029' 'USR1030' 'USR1031' 'USR1032' 'USR1033' 'USR1034' 'USR1035'
#  'USR1036' 'USR1037' 'USR1038' 'USR1039' 'USR1040' 'USR1041' 'USR1042'
# ...

# %%
new_ld
# Out:
#      lead_id demo_watched_date language  watched_percentage
# 0    USR1002          1/4/2022   Telugu                  42
# 1    USR1003          1/7/2022   Telugu                  81
# 2    USR1004          1/2/2022   Telugu                  35
# 3    USR1005          1/3/2022    Hindi                  38
# 4    USR1006         1/12/2022    Hindi                  54
# ..       ...               ...      ...                 ...
# 189  USR1317         2/25/2022  English                  48
# 190  USR1318         2/25/2022  English                  83
# 191  USR1319         2/28/2022  English                  84
# 192  USR1343         1/25/2022  English                  68
# 193  USR1348         2/27/2022  English                  72
#
# [192 rows x 4 columns]

# %%
lbd = pd.merge(new_lb, new_ld, how='inner', on='lead_id')
lbd
# Out:
#      lead_id  age  gender   current_city current_education  \
# 0    USR1001   16  FEMALE      Hyderabad      Intermediate
# 1    USR1002   20    MALE      Bengaluru            B.Tech
# 2    USR1003   20  FEMALE  Visakhapatnam            B.Tech
# 3    USR1004   16    MALE         Mumbai      Intermediate
# 4    USR1005   16    MALE        Chennai      Intermediate
# ..       ...  ...     ...            ...               ...
# 353  USR1356   21    MALE         Mumbai            Degree
# 354  USR1357   22    MALE        Chennai   Looking for Job
# 355  USR1358   25    MALE        Chennai            B.Tech
# 356  USR1359   18  FEMALE         Mumbai            B.Tech
# 357  USR1360   16    MALE         Mumbai      Intermediate
#
#        parent_occupation  lead_gen_source demo_watched_date language  \
# 0       Private Employee     social_media               NaN      NaN
# 1               Business   user_referrals          1/4/2022   Telugu
# ...

# %%
lbd.to_csv('lead_basic_and_demowatch.csv', index=False)

# %%
mod_lr = pd.read_csv('new_leads_reasons_for_no_interest.csv')

# %%
mod_lr
# Out:
#      lead_id reasons_for_not_interested_in_demo  \
# 0    USR1001                No time for student
# 1    USR1003                                NaN
# 2    USR1004                                NaN
# 3    USR1005                                NaN
# 4    USR1006                                NaN
# ..       ...                                ...
# 289  USR1356                       Can't afford
# 290  USR1357                       Can't afford
# 291  USR1358              Wants offline classes
# 292  USR1359            Will join in final year
# 293  USR1360            Will join in final year
#
#     reasons_for_not_interested_to_consider  \
# 0                                      NaN
# 1                      No time for student
# 2                    Wants offline classes
# 3                             Can't afford
# 4         Student not interested in domain
# ..                                     ...
# 289                                    NaN
# ...

# %%
unique_values(mod_lr)
# Out:
# Unique: LEAD_ID
# Total unique values: 294
# ['USR1001' 'USR1003' 'USR1004' 'USR1005' 'USR1006' 'USR1008' 'USR1009'
#  'USR1010' 'USR1014' 'USR1015' 'USR1016' 'USR1018' 'USR1019' 'USR1020'
#  'USR1021' 'USR1024' 'USR1026' 'USR1027' 'USR1028' 'USR1029' 'USR1030'
#  'USR1034' 'USR1035' 'USR1036' 'USR1038' 'USR1039' 'USR1040' 'USR1041'
#  'USR1043' 'USR1044' 'USR1045' 'USR1046' 'USR1048' 'USR1049' 'USR1050'
#  'USR1054' 'USR1055' 'USR1056' 'USR1058' 'USR1059' 'USR1060' 'USR1061'
#  'USR1064' 'USR1065' 'USR1066' 'USR1067' 'USR1068' 'USR1069' 'USR1070'
#  'USR1071' 'USR1074' 'USR1075' 'USR1076' 'USR1077' 'USR1078' 'USR1079'
#  'USR1080' 'USR1081' 'USR1082' 'USR1083' 'USR1084' 'USR1085' 'USR1086'
#  'USR1087' 'USR1088' 'USR1089' 'USR1090' 'USR1091' 'USR1094' 'USR1095'
#  'USR1096' 'USR1097' 'USR1098' 'USR1099' 'USR1100' 'USR1101' 'USR1104'
#  'USR1105' 'USR1106' 'USR1107' 'USR1108' 'USR1109' 'USR1110' 'USR1111'
#  'USR1114' 'USR1115' 'USR1117' 'USR1118' 'USR1119' 'USR1120' 'USR1121'
# ...

# %%
lbdr = pd.merge(lbd, mod_lr, how='left', on='lead_id')
lbdr
# Out:
#      lead_id  age  gender   current_city current_education  \
# 0    USR1001   16  FEMALE      Hyderabad      Intermediate
# 1    USR1002   20    MALE      Bengaluru            B.Tech
# 2    USR1003   20  FEMALE  Visakhapatnam            B.Tech
# 3    USR1004   16    MALE         Mumbai      Intermediate
# 4    USR1005   16    MALE        Chennai      Intermediate
# ..       ...  ...     ...            ...               ...
# 353  USR1356   21    MALE         Mumbai            Degree
# 354  USR1357   22    MALE        Chennai   Looking for Job
# 355  USR1358   25    MALE        Chennai            B.Tech
# 356  USR1359   18  FEMALE         Mumbai            B.Tech
# 357  USR1360   16    MALE         Mumbai      Intermediate
#
#        parent_occupation  lead_gen_source demo_watched_date language  \
# 0       Private Employee     social_media               NaN      NaN
# 1               Business   user_referrals          1/4/2022   Telugu
# ...

# %%
lbdr.to_csv('lead_basic_demowatch_reason.csv', index=False)

# %%
lbdr_sm = pd.merge(lbdr, sm, how='left', on='lead_id')
lbdr_sm
# Out:
#      lead_id  age  gender   current_city current_education  \
# 0    USR1001   16  FEMALE      Hyderabad      Intermediate
# 1    USR1002   20    MALE      Bengaluru            B.Tech
# 2    USR1003   20  FEMALE  Visakhapatnam            B.Tech
# 3    USR1004   16    MALE         Mumbai      Intermediate
# 4    USR1005   16    MALE        Chennai      Intermediate
# ..       ...  ...     ...            ...               ...
# 353  USR1356   21    MALE         Mumbai            Degree
# 354  USR1357   22    MALE        Chennai   Looking for Job
# 355  USR1358   25    MALE        Chennai            B.Tech
# 356  USR1359   18  FEMALE         Mumbai            B.Tech
# 357  USR1360   16    MALE         Mumbai      Intermediate
#
#        parent_occupation  lead_gen_source demo_watched_date language  \
# 0       Private Employee     social_media               NaN      NaN
# 1               Business   user_referrals          1/4/2022   Telugu
# ...

# %%
lbdr_sm.to_csv('lead_basic_demowatch_reason_managersinfo.csv', index=False)

# %%
lr_ld = pd.merge(mod_lr, new_ld, how='left', on='lead_id')
lr_ld
# Out:
#      lead_id reasons_for_not_interested_in_demo  \
# 0    USR1001                No time for student
# 1    USR1003                                NaN
# 2    USR1004                                NaN
# 3    USR1005                                NaN
# 4    USR1006                                NaN
# ..       ...                                ...
# 289  USR1356                       Can't afford
# 290  USR1357                       Can't afford
# 291  USR1358              Wants offline classes
# 292  USR1359            Will join in final year
# 293  USR1360            Will join in final year
#
#     reasons_for_not_interested_to_consider  \
# 0                                      NaN
# 1                      No time for student
# 2                    Wants offline classes
# 3                             Can't afford
# 4         Student not interested in domain
# ..                                     ...
# 289                                    NaN
# ...

# %%
lr_ld.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 294 entries, 0 to 293
# Data columns (total 7 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   lead_id                                 294 non-null    object
#  1   reasons_for_not_interested_in_demo      164 non-null    object
#  2   reasons_for_not_interested_to_consider  79 non-null     object
#  3   reasons_for_not_interested_to_convert   51 non-null     object
#  4   demo_watched_date                       129 non-null    object
#  5   language                                129 non-null    object
#  6   watched_percentage                      129 non-null    float64
# dtypes: float64(1), object(6)
# memory usage: 18.4+ KB
